# %%
#1: import necessary libraries
import numpy as np
import random
import math
from collections import deque
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import trange

# import environment classes
from Inventory_env_class import InventoryManagementEnv, NormalizeObservation, ReplayBuffer, DQN

# %%
#2: Device & environment setup
device = torch.device("cpu") #cpu was faster than cuda
print(f"Using device: {device}")

#import environment classes
from Inventory_env_class import InventoryManagementEnv, NormalizeObservation

#create environment
env = InventoryManagementEnv()
env = NormalizeObservation(env)

#inspect dimensions
obs_dim = env.observation_space.shape[0] #should be 6
n_actions = env.action_space.n #should be 3

print(f"Observation dim: {obs_dim}")
print(f"Action count: {n_actions}")
# Out:
# Using device: cpu
# Observation dim: 6
# Action count: 3

# %%
#3: Hyperparameters 
seed = 42 #for reproducibility
np.random.seed(seed) 
random.seed(seed)
torch.manual_seed(seed)

#training hyperparams
num_episodes = 2000 # laptop crashes every 40-50 min so I needed to keep it lower
max_steps_per_episode = 300 
batch_size = 64 #batch size
gamma = 0.99 #discount
lr = 1e-3 #learning rate
replay_capacity = 20000 #replay buffer

#Epsilon-greedy
eps_start = 1.0 #exploration
eps_end = 0.05 
eps_decay = 3000.0 #larger means slower decay

#target network update frequency
target_update_every = 1000

#for logging/plotting
print_interval = 50

# %%
#4: Initialize networks, optimizer, replay buffer
policy_net = DQN(obs_dim, n_actions).to(device) #policy network
target_net = DQN(obs_dim, n_actions).to(device) #target network
target_net.load_state_dict(policy_net.state_dict()) #copy weights
target_net.eval() #set to evaluation mode

optimizer = optim.Adam(policy_net.parameters(), lr=lr) #optimizer
replay_buffer = ReplayBuffer(capacity=replay_capacity) #replay buffer

# %%
#5: Helper functions
def get_epsilon(it):
    # smooth exponential decay
    return eps_end + (eps_start - eps_end) * math.exp(-1.0 * it / eps_decay)

#epsilon-greedy
def select_action(state, epsilon):
    # state: numpy array (observation)
    if random.random() < epsilon:
        return random.randrange(n_actions)
    else:
        with torch.no_grad():
            t = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            qvals = policy_net(t)
            return int(qvals.argmax().cpu().numpy())

#loss
mse_loss = nn.MSELoss()

#optimize model
def optimize_model():
    if len(replay_buffer) < batch_size:
        return None
    states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
    # convert to tensors
    states_t = torch.tensor(states, dtype=torch.float32, device=device)
    actions_t = torch.tensor(actions, dtype=torch.long, device=device).unsqueeze(1)
    rewards_t = torch.tensor(rewards, dtype=torch.float32, device=device).unsqueeze(1)
    next_states_t = torch.tensor(next_states, dtype=torch.float32, device=device)
    dones_t = torch.tensor(dones, dtype=torch.float32, device=device).unsqueeze(1)

    # calculate Q(s,a)
    q_values = policy_net(states_t).gather(1, actions_t)

    # calculate Q(s',a')
    with torch.no_grad():
        next_q = target_net(next_states_t).max(1)[0].unsqueeze(1)
        target_q = rewards_t + (1.0 - dones_t) * gamma * next_q

    loss = mse_loss(q_values, target_q)

    # optimize
    optimizer.zero_grad()
    loss.backward()
    # simple gradient clipping for stability
    nn.utils.clip_grad_norm_(policy_net.parameters(), 1.0)
    optimizer.step()

    #return loss
    return loss.item()

# %%
#6: Training loop with clear display of metrics
total_steps = 0
loss_history = []
reward_history = []
eps_history = []
avg_loss_per_episode = []  #tracking average loss per episode

print("=" * 60)
print("Starting DQN Training for Inventory Management")
print("=" * 60)

#main loop
for episode in range(1, num_episodes + 1):
    #reset env. at the start of each episode
    state, _ = env.reset()
    episode_reward = 0.0
    episode_losses = []
    
    #run one episode
    for t in range(max_steps_per_episode):
        #get epsilon
        epsilon = get_epsilon(total_steps)
        
        #select action
        action = select_action(state, epsilon)
        
        #take action
        next_state, reward, terminated, truncated, info = env.step(action)
        
        #store transition
        done = bool(terminated or truncated)
        replay_buffer.push(state, action, reward, next_state, float(done))
        
        #update and move to nect state
        state = next_state
        episode_reward += reward
        total_steps += 1
        
        #optimize model
        loss_val = optimize_model()
        if loss_val is not None:
            episode_losses.append(loss_val)
            loss_history.append(loss_val)
        
        #update target network
        if total_steps % target_update_every == 0:
            target_net.load_state_dict(policy_net.state_dict())
        
        #end episode
        if done:
            break
    
    #save metrics
    reward_history.append(episode_reward)
    eps_history.append(epsilon)
    
    #track average loss
    avg_loss = np.mean(episode_losses) if episode_losses else 0.0
    avg_loss_per_episode.append(avg_loss)
    
    #print metrics
    #show the total rewards per episode, epsilon value, and also tje average mse loss
    if episode % print_interval == 0 or episode == 1:
        recent_rewards_avg = np.mean(reward_history[-print_interval:])
        print(f"Episode {episode:5d}/{num_episodes} | "
              f"Total Reward: {episode_reward:8.2f} | "
              f"Avg Reward (last {print_interval}): {recent_rewards_avg:8.2f} | "
              f"Epsilon: {epsilon:.4f} | "
              f"Avg MSE Loss: {avg_loss:.6f}")

print("=" * 60)
print("Training Complete")
print("=" * 60)
# Out:
# ============================================================
# Starting DQN Training for Inventory Management
# ============================================================
# Episode     1/2000 | Total Reward: -13575.54 | Avg Reward (last 50): -13575.54 | Epsilon: 0.9099 | Avg MSE Loss: 965.262771
# Episode    50/2000 | Total Reward: -11647.39 | Avg Reward (last 50): -12156.11 | Epsilon: 0.0564 | Avg MSE Loss: 224.739550
# Episode   100/2000 | Total Reward: -11946.35 | Avg Reward (last 50): -11834.05 | Epsilon: 0.0500 | Avg MSE Loss: 249.856196
# Episode   150/2000 | Total Reward: -11630.52 | Avg Reward (last 50): -11911.51 | Epsilon: 0.0500 | Avg MSE Loss: 254.817324
# Episode   200/2000 | Total Reward: -12135.13 | Avg Reward (last 50): -12018.84 | Epsilon: 0.0500 | Avg MSE Loss: 262.955351
# Episode   250/2000 | Total Reward: -12222.60 | Avg Reward (last 50): -12058.23 | Epsilon: 0.0500 | Avg MSE Loss: 259.523517
# Episode   300/2000 | Total Reward: -12488.15 | Avg Reward (last 50): -12025.33 | Epsilon: 0.0500 | Avg MSE Loss: 267.717360
# Episode   350/2000 | Total Reward: -12217.88 | Avg Reward (last 50): -12089.57 | Epsilon: 0.0500 | Avg MSE Loss: 282.819435
# Episode   400/2000 | Total Reward: -12047.60 | Avg Reward (last 50): -12012.67 | Epsilon: 0.0500 | Avg MSE Loss: 294.983745
# Episode   450/2000 | Total Reward: -12128.40 | Avg Reward (last 50): -12168.77 | Epsilon: 0.0500 | Avg MSE Loss: 274.280485
# Episode   500/2000 | Total Reward: -12139.93 | Avg Reward (last 50): -11983.97 | Epsilon: 0.0500 | Avg MSE Loss: 279.873810
# Episode   550/2000 | Total Reward: -12354.23 | Avg Reward (last 50): -11967.18 | Epsilon: 0.0500 | Avg MSE Loss: 300.935772
# Episode   600/2000 | Total Reward: -12422.93 | Avg Reward (last 50): -12017.26 | Epsilon: 0.0500 | Avg MSE Loss: 293.047220
# Episode   650/2000 | Total Reward: -11600.45 | Avg Reward (last 50): -12013.39 | Epsilon: 0.0500 | Avg MSE Loss: 301.439049
# Episode   700/2000 | Total Reward: -12236.79 | Avg Reward (last 50): -12062.44 | Epsilon: 0.0500 | Avg MSE Loss: 302.871816
# Episode   750/2000 | Total Reward: -11207.75 | Avg Reward (last 50): -11920.28 | Epsilon: 0.0500 | Avg MSE Loss: 305.202887
# Episode   800/2000 | Total Reward: -11774.69 | Avg Reward (last 50): -11908.87 | Epsilon: 0.0500 | Avg MSE Loss: 316.270303
# Episode   850/2000 | Total Reward: -12337.96 | Avg Reward (last 50): -12020.20 | Epsilon: 0.0500 | Avg MSE Loss: 306.492673
# Episode   900/2000 | Total Reward: -11589.10 | Avg Reward (last 50): -11970.27 | Epsilon: 0.0500 | Avg MSE Loss: 314.727010
# Episode   950/2000 | Total Reward: -11486.39 | Avg Reward (last 50): -11982.04 | Epsilon: 0.0500 | Avg MSE Loss: 297.671901
# Episode  1000/2000 | Total Reward: -11702.64 | Avg Reward (last 50): -11820.25 | Epsilon: 0.0500 | Avg MSE Loss: 312.857814
# Episode  1050/2000 | Total Reward: -12246.81 | Avg Reward (last 50): -11918.41 | Epsilon: 0.0500 | Avg MSE Loss: 328.750530
# Episode  1100/2000 | Total Reward: -12060.39 | Avg Reward (last 50): -11946.90 | Epsilon: 0.0500 | Avg MSE Loss: 317.122921
# Episode  1150/2000 | Total Reward: -11525.47 | Avg Reward (last 50): -11928.48 | Epsilon: 0.0500 | Avg MSE Loss: 301.042617
# Episode  1200/2000 | Total Reward: -11692.35 | Avg Reward (last 50): -11903.92 | Epsilon: 0.0500 | Avg MSE Loss: 292.519117
# Episode  1250/2000 | Total Reward: -12410.51 | Avg Reward (last 50): -11987.90 | Epsilon: 0.0500 | Avg MSE Loss: 311.156938
# Episode  1300/2000 | Total Reward: -12258.43 | Avg Reward (last 50): -11969.51 | Epsilon: 0.0500 | Avg MSE Loss: 331.993433
# Episode  1350/2000 | Total Reward: -11828.77 | Avg Reward (last 50): -11868.66 | Epsilon: 0.0500 | Avg MSE Loss: 297.735322
# Episode  1400/2000 | Total Reward: -11452.85 | Avg Reward (last 50): -12000.97 | Epsilon: 0.0500 | Avg MSE Loss: 336.988988
# Episode  1450/2000 | Total Reward: -11715.50 | Avg Reward (last 50): -11922.95 | Epsilon: 0.0500 | Avg MSE Loss: 330.414864
# Episode  1500/2000 | Total Reward: -11529.08 | Avg Reward (last 50): -11874.72 | Epsilon: 0.0500 | Avg MSE Loss: 297.608532
# Episode  1550/2000 | Total Reward: -12631.30 | Avg Reward (last 50): -11950.29 | Epsilon: 0.0500 | Avg MSE Loss: 308.729430
# Episode  1600/2000 | Total Reward: -11822.56 | Avg Reward (last 50): -11895.74 | Epsilon: 0.0500 | Avg MSE Loss: 339.635297
# Episode  1650/2000 | Total Reward: -12308.63 | Avg Reward (last 50): -11979.27 | Epsilon: 0.0500 | Avg MSE Loss: 301.559951
# Episode  1700/2000 | Total Reward: -11791.48 | Avg Reward (last 50): -11835.39 | Epsilon: 0.0500 | Avg MSE Loss: 326.754273
# Episode  1750/2000 | Total Reward: -11576.72 | Avg Reward (last 50): -11827.83 | Epsilon: 0.0500 | Avg MSE Loss: 331.070844
# Episode  1800/2000 | Total Reward: -12711.59 | Avg Reward (last 50): -11937.45 | Epsilon: 0.0500 | Avg MSE Loss: 292.390384
# Episode  1850/2000 | Total Reward: -11826.78 | Avg Reward (last 50): -11833.02 | Epsilon: 0.0500 | Avg MSE Loss: 317.106703
# Episode  1900/2000 | Total Reward: -11558.54 | Avg Reward (last 50): -11935.86 | Epsilon: 0.0500 | Avg MSE Loss: 274.505686
# Episode  1950/2000 | Total Reward: -11329.20 | Avg Reward (last 50): -11782.51 | Epsilon: 0.0500 | Avg MSE Loss: 337.108049
# Episode  2000/2000 | Total Reward: -11923.56 | Avg Reward (last 50): -11902.02 | Epsilon: 0.0500 | Avg MSE Loss: 305.643790
# ============================================================
# Training Complete
# ============================================================

# %%
#7: Save the trained model
torch.save(policy_net.state_dict(), "inventory_dqn_policy.pth") 
print("Saved policy to inventory_dqn_policy.pth")
# Out:
# Saved policy to inventory_dqn_policy.pth

# %%
#8: Quick plots of reward and loss
# smooth reward
def smooth(x, w=50):
    if len(x) < w:
        return x
    return np.convolve(x, np.ones(w)/w, mode='valid')

# plot
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(reward_history, alpha=0.4, label='episode reward')
plt.plot(range(len(smooth(reward_history))), smooth(reward_history), label='smoothed')
plt.title("Episode reward")
plt.legend()

# plot loss
plt.subplot(1,2,2)
if loss_history: 
    plt.plot(loss_history, alpha=0.6) 
    plt.title("Training MSE loss (per update)")
else:
    plt.title("No loss data")
plt.tight_layout()
plt.show()

# %%
#9: Test the trained policy 
def test_policy(policy_model, episodes=10, render=True):
    policy_model.eval() # set model to eval mode
    results = [] 
    for ep in range(episodes):  # loop over episodes
        state, _ = env.reset()
        ep_reward = 0.0 # initialize episode reward
        for t in range(env.max_steps):
            with torch.no_grad():
                st = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0) # convert state to tensor
                action = int(policy_model(st).argmax().cpu().numpy()) # get action from policy model
            next_state, reward, terminated, truncated, info = env.step(action) # take action in environment
            ep_reward += reward #update episode reward
            if render: 
                print(f"\n Test Episode {ep+1} | Step {t+1}")
                env.render()
                print(f"Action chosen: {action}, Reward: {reward:.2f}")
            state = next_state #update state
            if terminated or truncated: #end episode
                break
        results.append(ep_reward) #store episode reward
        print(f"Test Episode {ep+1} finished | Total reward: {ep_reward:.2f}") 
    return results

#test
test_results = test_policy(policy_net, episodes=10, render=True) # test policy
print("Test episode rewards:", test_results)
# Out:
# c:\Users\siona\miniconda3\envs\myenv\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.max_steps to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.max_steps` for environment variables or `env.get_wrapper_attr('max_steps')` that will search the reminding wrappers.
#   logger.warn(
#  Test Episode 1 | Step 1
# Step: 1
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.57, Product Price: 20.00
# Demand: 12.98, Cash: 995.11
# Action chosen: 1, Reward: -65.02
#
#  Test Episode 1 | Step 2
# Step: 2
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.38, Product Price: 19.82
# Demand: 14.80, Cash: 990.54
# Action chosen: 1, Reward: -74.19
#
#  Test Episode 1 | Step 3
# Step: 3
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.21, Product Price: 19.82
# Demand: 13.25, Cash: 986.15
# Action chosen: 1, Reward: -66.55
#
#  Test Episode 1 | Step 4
# Step: 4
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.13, Product Price: 19.53
# Demand: 9.85, Cash: 981.94
# Action chosen: 1, Reward: -49.65
#
#  Test Episode 1 | Step 5
# Step: 5
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.02, Product Price: 19.66
# Demand: 9.69, Cash: 1001.47
# Action chosen: 2, Reward: -14.10
#
#  Test Episode 1 | Step 6
# Step: 6
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.30, Product Price: 20.12
# Demand: 8.08, Cash: 997.45
# Action chosen: 1, Reward: -40.70
#
#  Test Episode 1 | Step 7
# Step: 7
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.33, Product Price: 19.90
# Demand: 11.16, Cash: 993.16
# Action chosen: 1, Reward: -56.19
#
#  Test Episode 1 | Step 8
# Step: 8
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.47, Product Price: 19.71
# Demand: 8.24, Cash: 1013.06
# Action chosen: 2, Reward: -6.51
#
#  Test Episode 1 | Step 9
# Step: 9
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.59, Product Price: 19.61
# Demand: 11.97, Cash: 1008.58
# Action chosen: 1, Reward: -60.17
#
#  Test Episode 1 | Step 10
# Step: 10
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.77, Product Price: 19.69
# Demand: 10.82, Cash: 1003.99
# Action chosen: 1, Reward: -54.51
#
#  Test Episode 1 | Step 11
# Step: 11
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.80, Product Price: 19.58
# Demand: 9.93, Cash: 1023.68
# Action chosen: 2, Reward: -15.18
#
#  Test Episode 1 | Step 12
# Step: 12
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.85, Product Price: 19.43
# Demand: 7.22, Cash: 1018.88
# Action chosen: 1, Reward: -36.39
#
#  Test Episode 1 | Step 13
# Step: 13
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.40, Product Price: 19.54
# Demand: 10.86, Cash: 1014.03
# Action chosen: 1, Reward: -54.69
#
#  Test Episode 1 | Step 14
# Step: 14
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.53, Product Price: 19.70
# Demand: 5.24, Cash: 1033.57
# Action chosen: 2, Reward: 8.13
#
#  Test Episode 1 | Step 15
# Step: 15
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.79, Product Price: 19.40
# Demand: 9.65, Cash: 1029.04
# Action chosen: 1, Reward: -48.56
#
#  Test Episode 1 | Step 16
# Step: 16
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.84, Product Price: 19.23
# Demand: 6.37, Cash: 1024.25
# Action chosen: 1, Reward: -32.24
#
#  Test Episode 1 | Step 17
# Step: 17
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.73, Product Price: 19.06
# Demand: 12.84, Cash: 1043.48
# Action chosen: 2, Reward: -30.17
#
#  Test Episode 1 | Step 18
# Step: 18
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.57, Product Price: 19.40
# Demand: 8.90, Cash: 1038.75
# Action chosen: 1, Reward: -44.82
#
#  Test Episode 1 | Step 19
# Step: 19
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.86, Product Price: 19.75
# Demand: 9.90, Cash: 1034.18
# Action chosen: 1, Reward: -49.88
#
#  Test Episode 1 | Step 20
# Step: 20
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.63, Product Price: 19.43
# Demand: 11.35, Cash: 1053.93
# Action chosen: 2, Reward: -22.19
#
#  Test Episode 1 | Step 21
# Step: 21
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.94, Product Price: 19.02
# Demand: 15.04, Cash: 1049.30
# Action chosen: 1, Reward: -75.48
#
#  Test Episode 1 | Step 22
# Step: 22
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.91, Product Price: 19.44
# Demand: 8.21, Cash: 1044.36
# Action chosen: 1, Reward: -41.47
#
#  Test Episode 1 | Step 23
# Step: 23
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.87, Product Price: 19.66
# Demand: 9.46, Cash: 1063.81
# Action chosen: 2, Reward: -13.04
#
#  Test Episode 1 | Step 24
# Step: 24
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.79, Product Price: 19.63
# Demand: 10.75, Cash: 1058.93
# Action chosen: 1, Reward: -54.07
#
#  Test Episode 1 | Step 25
# Step: 25
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.74, Product Price: 19.55
# Demand: 9.17, Cash: 1054.15
# Action chosen: 1, Reward: -46.23
#
#  Test Episode 1 | Step 26
# Step: 26
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.94, Product Price: 19.29
# Demand: 12.94, Cash: 1073.69
# Action chosen: 2, Reward: -30.33
#
#  Test Episode 1 | Step 27
# Step: 27
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.87, Product Price: 19.27
# Demand: 7.39, Cash: 1068.75
# Action chosen: 1, Reward: -37.27
#
#  Test Episode 1 | Step 28
# Step: 28
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.89, Product Price: 19.05
# Demand: 8.88, Cash: 1063.88
# Action chosen: 1, Reward: -44.79
#
#  Test Episode 1 | Step 29
# Step: 29
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.67, Product Price: 19.00
# Demand: 14.18, Cash: 1082.93
# Action chosen: 2, Reward: -37.05
#
#  Test Episode 1 | Step 30
# Step: 30
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.83, Product Price: 18.83
# Demand: 5.97, Cash: 1078.26
# Action chosen: 1, Reward: -30.17
#
#  Test Episode 1 | Step 31
# Step: 31
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.86, Product Price: 18.57
# Demand: 8.52, Cash: 1073.43
# Action chosen: 1, Reward: -43.00
#
#  Test Episode 1 | Step 32
# Step: 32
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.80, Product Price: 18.48
# Demand: 7.01, Cash: 1092.00
# Action chosen: 2, Reward: -1.70
#
#  Test Episode 1 | Step 33
# Step: 33
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.84, Product Price: 18.41
# Demand: 7.13, Cash: 1087.20
# Action chosen: 1, Reward: -35.97
#
#  Test Episode 1 | Step 34
# Step: 34
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.91, Product Price: 18.64
# Demand: 13.81, Cash: 1082.36
# Action chosen: 1, Reward: -69.44
#
#  Test Episode 1 | Step 35
# Step: 35
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.76, Product Price: 18.57
# Demand: 9.96, Cash: 1100.99
# Action chosen: 2, Reward: -16.37
#
#  Test Episode 1 | Step 36
# Step: 36
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.45, Product Price: 18.77
# Demand: 10.37, Cash: 1096.23
# Action chosen: 1, Reward: -52.13
#
#  Test Episode 1 | Step 37
# Step: 37
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.39, Product Price: 18.63
# Demand: 14.40, Cash: 1091.79
# Action chosen: 1, Reward: -72.39
#
#  Test Episode 1 | Step 38
# Step: 38
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.22, Product Price: 18.40
# Demand: 14.01, Cash: 1110.42
# Action chosen: 2, Reward: -36.61
#
#  Test Episode 1 | Step 39
# Step: 39
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.24, Product Price: 18.50
# Demand: 14.53, Cash: 1106.20
# Action chosen: 1, Reward: -72.94
#
#  Test Episode 1 | Step 40
# Step: 40
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.04, Product Price: 18.28
# Demand: 9.22, Cash: 1101.96
# Action chosen: 1, Reward: -46.49
#
#  Test Episode 1 | Step 41
# Step: 41
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.32, Product Price: 18.36
# Demand: 8.18, Cash: 1120.24
# Action chosen: 2, Reward: -7.83
#
#  Test Episode 1 | Step 42
# Step: 42
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.31, Product Price: 18.75
# Demand: 11.39, Cash: 1115.92
# Action chosen: 1, Reward: -57.26
#
#  Test Episode 1 | Step 43
# Step: 43
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.48, Product Price: 19.03
# Demand: 8.61, Cash: 1111.62
# Action chosen: 1, Reward: -43.43
#
#  Test Episode 1 | Step 44
# Step: 44
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.28, Product Price: 19.37
# Demand: 9.52, Cash: 1130.65
# Action chosen: 2, Reward: -13.77
#
#  Test Episode 1 | Step 45
# Step: 45
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.18, Product Price: 19.55
# Demand: 11.22, Cash: 1126.36
# Action chosen: 1, Reward: -56.38
#
#  Test Episode 1 | Step 46
# Step: 46
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.08, Product Price: 19.25
# Demand: 4.53, Cash: 1122.18
# Action chosen: 1, Reward: -23.03
#
#  Test Episode 1 | Step 47
# Step: 47
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.39, Product Price: 18.97
# Demand: 15.26, Cash: 1141.43
# Action chosen: 2, Reward: -42.24
#
#  Test Episode 1 | Step 48
# Step: 48
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.32, Product Price: 18.72
# Demand: 14.74, Cash: 1137.04
# Action chosen: 1, Reward: -74.02
#
#  Test Episode 1 | Step 49
# Step: 49
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.39, Product Price: 18.57
# Demand: 11.99, Cash: 1132.72
# Action chosen: 1, Reward: -60.36
#
#  Test Episode 1 | Step 50
# Step: 50
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.75, Product Price: 18.78
# Demand: 11.12, Cash: 1151.29
# Action chosen: 2, Reward: -22.25
#
#  Test Episode 1 | Step 51
# Step: 51
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.69, Product Price: 18.86
# Demand: 9.22, Cash: 1146.55
# Action chosen: 1, Reward: -46.41
#
#  Test Episode 1 | Step 52
# Step: 52
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.51, Product Price: 18.66
# Demand: 7.02, Cash: 1141.85
# Action chosen: 1, Reward: -35.51
#
#  Test Episode 1 | Step 53
# Step: 53
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.71, Product Price: 18.88
# Demand: 10.86, Cash: 1160.51
# Action chosen: 2, Reward: -20.82
#
#  Test Episode 1 | Step 54
# Step: 54
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.83, Product Price: 19.19
# Demand: 6.72, Cash: 1155.81
# Action chosen: 1, Reward: -33.88
#
#  Test Episode 1 | Step 55
# Step: 55
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.09, Product Price: 19.38
# Demand: 10.72, Cash: 1150.98
# Action chosen: 1, Reward: -54.01
#
#  Test Episode 1 | Step 56
# Step: 56
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.43, Product Price: 19.66
# Demand: 11.05, Cash: 1170.36
# Action chosen: 2, Reward: -21.10
#
#  Test Episode 1 | Step 57
# Step: 57
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.60, Product Price: 19.87
# Demand: 7.37, Cash: 1164.93
# Action chosen: 1, Reward: -37.16
#
#  Test Episode 1 | Step 58
# Step: 58
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.61, Product Price: 19.60
# Demand: 9.88, Cash: 1184.80
# Action chosen: 2, Reward: -14.61
#
#  Test Episode 1 | Step 59
# Step: 59
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.55, Product Price: 19.55
# Demand: 7.82, Cash: 1179.19
# Action chosen: 1, Reward: -39.29
#
#  Test Episode 1 | Step 60
# Step: 60
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.29, Product Price: 19.32
# Demand: 10.93, Cash: 1173.64
# Action chosen: 1, Reward: -54.94
#
#  Test Episode 1 | Step 61
# Step: 61
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.45, Product Price: 19.43
# Demand: 4.89, Cash: 1168.35
# Action chosen: 1, Reward: -24.85
#
#  Test Episode 1 | Step 62
# Step: 62
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.39, Product Price: 19.44
# Demand: 9.12, Cash: 1187.79
# Action chosen: 2, Reward: -11.38
#
#  Test Episode 1 | Step 63
# Step: 63
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.41, Product Price: 19.43
# Demand: 16.39, Cash: 1182.40
# Action chosen: 1, Reward: -82.26
#
#  Test Episode 1 | Step 64
# Step: 64
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.03, Product Price: 19.30
# Demand: 16.33, Cash: 1176.99
# Action chosen: 1, Reward: -82.03
#
#  Test Episode 1 | Step 65
# Step: 65
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.18, Product Price: 19.48
# Demand: 5.92, Cash: 1196.29
# Action chosen: 2, Reward: 4.48
#
#  Test Episode 1 | Step 66
# Step: 66
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.40, Product Price: 19.28
# Demand: 10.43, Cash: 1191.11
# Action chosen: 1, Reward: -52.44
#
#  Test Episode 1 | Step 67
# Step: 67
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.11, Product Price: 19.11
# Demand: 10.69, Cash: 1185.71
# Action chosen: 1, Reward: -53.85
#
#  Test Episode 1 | Step 68
# Step: 68
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.32, Product Price: 18.96
# Demand: 9.34, Cash: 1204.82
# Action chosen: 2, Reward: -12.79
#
#  Test Episode 1 | Step 69
# Step: 69
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.19, Product Price: 18.56
# Demand: 16.40, Cash: 1199.51
# Action chosen: 1, Reward: -82.28
#
#  Test Episode 1 | Step 70
# Step: 70
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.28, Product Price: 18.42
# Demand: 14.02, Cash: 1194.31
# Action chosen: 1, Reward: -70.52
#
#  Test Episode 1 | Step 71
# Step: 71
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.21, Product Price: 18.27
# Demand: 7.97, Cash: 1212.73
# Action chosen: 2, Reward: -6.65
#
#  Test Episode 1 | Step 72
# Step: 72
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.56, Product Price: 18.37
# Demand: 12.61, Cash: 1207.52
# Action chosen: 1, Reward: -63.35
#
#  Test Episode 1 | Step 73
# Step: 73
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.45, Product Price: 18.69
# Demand: 8.65, Cash: 1201.96
# Action chosen: 1, Reward: -43.65
#
#  Test Episode 1 | Step 74
# Step: 74
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.41, Product Price: 18.82
# Demand: 12.35, Cash: 1220.65
# Action chosen: 2, Reward: -28.25
#
#  Test Episode 1 | Step 75
# Step: 75
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.05, Product Price: 19.34
# Demand: 9.82, Cash: 1215.24
# Action chosen: 1, Reward: -49.39
#
#  Test Episode 1 | Step 76
# Step: 76
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.35, Product Price: 19.42
# Demand: 15.04, Cash: 1210.19
# Action chosen: 1, Reward: -75.58
#
#  Test Episode 1 | Step 77
# Step: 77
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.24, Product Price: 19.28
# Demand: 8.07, Cash: 1229.60
# Action chosen: 2, Reward: -6.12
#
#  Test Episode 1 | Step 78
# Step: 78
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.16, Product Price: 19.24
# Demand: 6.99, Cash: 1224.37
# Action chosen: 1, Reward: -35.26
#
#  Test Episode 1 | Step 79
# Step: 79
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.05, Product Price: 19.08
# Demand: 8.98, Cash: 1219.21
# Action chosen: 1, Reward: -45.32
#
#  Test Episode 1 | Step 80
# Step: 80
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.53, Product Price: 19.07
# Demand: 10.61, Cash: 1238.28
# Action chosen: 2, Reward: -19.16
#
#  Test Episode 1 | Step 81
# Step: 81
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.29, Product Price: 19.07
# Demand: 9.88, Cash: 1232.75
# Action chosen: 1, Reward: -49.70
#
#  Test Episode 1 | Step 82
# Step: 82
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.58, Product Price: 19.29
# Demand: 6.63, Cash: 1227.46
# Action chosen: 1, Reward: -33.57
#
#  Test Episode 1 | Step 83
# Step: 83
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.77, Product Price: 19.31
# Demand: 7.16, Cash: 1246.75
# Action chosen: 2, Reward: -1.73
#
#  Test Episode 1 | Step 84
# Step: 84
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.64, Product Price: 19.04
# Demand: 10.65, Cash: 1240.98
# Action chosen: 1, Reward: -53.55
#
#  Test Episode 1 | Step 85
# Step: 85
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.56, Product Price: 19.11
# Demand: 13.40, Cash: 1235.34
# Action chosen: 1, Reward: -67.38
#
#  Test Episode 1 | Step 86
# Step: 86
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.38, Product Price: 19.14
# Demand: 7.91, Cash: 1254.45
# Action chosen: 2, Reward: -5.64
#
#  Test Episode 1 | Step 87
# Step: 87
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.35, Product Price: 19.32
# Demand: 13.53, Cash: 1249.07
# Action chosen: 1, Reward: -67.93
#
#  Test Episode 1 | Step 88
# Step: 88
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.40, Product Price: 19.25
# Demand: 11.26, Cash: 1243.71
# Action chosen: 1, Reward: -56.69
#
#  Test Episode 1 | Step 89
# Step: 89
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.44, Product Price: 19.15
# Demand: 9.65, Cash: 1262.96
# Action chosen: 2, Reward: -14.21
#
#  Test Episode 1 | Step 90
# Step: 90
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.57, Product Price: 19.08
# Demand: 8.08, Cash: 1257.52
# Action chosen: 1, Reward: -40.70
#
#  Test Episode 1 | Step 91
# Step: 91
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.42, Product Price: 18.96
# Demand: 14.03, Cash: 1251.95
# Action chosen: 1, Reward: -70.54
#
#  Test Episode 1 | Step 92
# Step: 92
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.28, Product Price: 18.93
# Demand: 8.64, Cash: 1270.91
# Action chosen: 2, Reward: -9.45
#
#  Test Episode 1 | Step 93
# Step: 93
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.35, Product Price: 19.08
# Demand: 12.49, Cash: 1265.63
# Action chosen: 1, Reward: -62.73
#
#  Test Episode 1 | Step 94
# Step: 94
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.71, Product Price: 18.86
# Demand: 7.11, Cash: 1260.27
# Action chosen: 1, Reward: -35.93
#
#  Test Episode 1 | Step 95
# Step: 95
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.21, Product Price: 18.96
# Demand: 11.24, Cash: 1279.13
# Action chosen: 2, Reward: -22.56
#
#  Test Episode 1 | Step 96
# Step: 96
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.92, Product Price: 18.90
# Demand: 9.06, Cash: 1273.92
# Action chosen: 1, Reward: -45.59
#
#  Test Episode 1 | Step 97
# Step: 97
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.97, Product Price: 18.70
# Demand: 13.47, Cash: 1269.01
# Action chosen: 1, Reward: -67.75
#
#  Test Episode 1 | Step 98
# Step: 98
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.83, Product Price: 18.66
# Demand: 8.83, Cash: 1287.71
# Action chosen: 2, Reward: -10.65
#
#  Test Episode 1 | Step 99
# Step: 99
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.41, Product Price: 18.74
# Demand: 14.77, Cash: 1282.88
# Action chosen: 1, Reward: -74.13
#
#  Test Episode 1 | Step 100
# Step: 100
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.57, Product Price: 18.86
# Demand: 5.70, Cash: 1278.47
# Action chosen: 1, Reward: -28.92
#
#  Test Episode 1 | Step 101
# Step: 101
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.52, Product Price: 18.80
# Demand: 8.58, Cash: 1297.33
# Action chosen: 2, Reward: -9.25
#
#  Test Episode 1 | Step 102
# Step: 102
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.44, Product Price: 19.07
# Demand: 12.97, Cash: 1292.81
# Action chosen: 1, Reward: -65.17
#
#  Test Episode 1 | Step 103
# Step: 103
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.44, Product Price: 19.14
# Demand: 8.33, Cash: 1288.37
# Action chosen: 1, Reward: -42.07
#
#  Test Episode 1 | Step 104
# Step: 104
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.61, Product Price: 19.22
# Demand: 5.52, Cash: 1307.51
# Action chosen: 2, Reward: 6.35
#
#  Test Episode 1 | Step 105
# Step: 105
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.41, Product Price: 19.53
# Demand: 10.90, Cash: 1302.90
# Action chosen: 1, Reward: -54.78
#
#  Test Episode 1 | Step 106
# Step: 106
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.00, Product Price: 19.14
# Demand: 11.26, Cash: 1322.43
# Action chosen: 2, Reward: -21.88
#
#  Test Episode 1 | Step 107
# Step: 107
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.02, Product Price: 19.01
# Demand: 8.74, Cash: 1318.43
# Action chosen: 1, Reward: -43.88
#
#  Test Episode 1 | Step 108
# Step: 108
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.96, Product Price: 19.10
# Demand: 12.14, Cash: 1314.41
# Action chosen: 1, Reward: -61.00
#
#  Test Episode 1 | Step 109
# Step: 109
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.76, Product Price: 18.98
# Demand: 7.61, Cash: 1310.45
# Action chosen: 1, Reward: -38.43
#
#  Test Episode 1 | Step 110
# Step: 110
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.86, Product Price: 18.86
# Demand: 9.18, Cash: 1329.43
# Action chosen: 2, Reward: -12.13
#
#  Test Episode 1 | Step 111
# Step: 111
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.02, Product Price: 18.60
# Demand: 9.32, Cash: 1325.57
# Action chosen: 1, Reward: -46.92
#
#  Test Episode 1 | Step 112
# Step: 112
# Raw Inventory: 4.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.95, Product Price: 18.90
# Demand: 15.62, Cash: 1321.55
# Action chosen: 1, Reward: -78.50
#
#  Test Episode 1 | Step 113
# Step: 113
# Raw Inventory: 2.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.78, Product Price: 19.39
# Demand: 11.79, Cash: 1340.45
# Action chosen: 2, Reward: -25.25
#
#  Test Episode 1 | Step 114
# Step: 114
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.13, Product Price: 19.38
# Demand: 9.94, Cash: 1336.67
# Action chosen: 1, Reward: -50.02
#
#  Test Episode 1 | Step 115
# Step: 115
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.10, Product Price: 19.51
# Demand: 11.64, Cash: 1356.04
# Action chosen: 2, Reward: -23.90
#
#  Test Episode 1 | Step 116
# Step: 116
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.02, Product Price: 19.79
# Demand: 5.60, Cash: 1351.95
# Action chosen: 1, Reward: -28.18
#
#  Test Episode 1 | Step 117
# Step: 117
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.47, Product Price: 19.73
# Demand: 11.83, Cash: 1347.93
# Action chosen: 1, Reward: -59.46
#
#  Test Episode 1 | Step 118
# Step: 118
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.51, Product Price: 19.83
# Demand: 11.10, Cash: 1367.66
# Action chosen: 2, Reward: -20.85
#
#  Test Episode 1 | Step 119
# Step: 119
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.61, Product Price: 19.80
# Demand: 12.92, Cash: 1363.15
# Action chosen: 1, Reward: -64.82
#
#  Test Episode 1 | Step 120
# Step: 120
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.76, Product Price: 19.87
# Demand: 10.70, Cash: 1358.54
# Action chosen: 1, Reward: -53.80
#
#  Test Episode 1 | Step 121
# Step: 121
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.77, Product Price: 19.82
# Demand: 11.98, Cash: 1378.42
# Action chosen: 2, Reward: -25.12
#
#  Test Episode 1 | Step 122
# Step: 122
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.76, Product Price: 20.34
# Demand: 13.28, Cash: 1373.65
# Action chosen: 1, Reward: -66.60
#
#  Test Episode 1 | Step 123
# Step: 123
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.92, Product Price: 20.68
# Demand: 14.38, Cash: 1368.89
# Action chosen: 1, Reward: -72.18
#
#  Test Episode 1 | Step 124
# Step: 124
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.68, Product Price: 20.65
# Demand: 7.10, Cash: 1389.57
# Action chosen: 2, Reward: 0.06
#
#  Test Episode 1 | Step 125
# Step: 125
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.44, Product Price: 20.76
# Demand: 9.40, Cash: 1384.89
# Action chosen: 1, Reward: -47.22
#
#  Test Episode 1 | Step 126
# Step: 126
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.35, Product Price: 20.78
# Demand: 10.47, Cash: 1380.45
# Action chosen: 1, Reward: -52.67
#
#  Test Episode 1 | Step 127
# Step: 127
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.45, Product Price: 20.74
# Demand: 14.39, Cash: 1401.23
# Action chosen: 2, Reward: -36.25
#
#  Test Episode 1 | Step 128
# Step: 128
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.56, Product Price: 20.84
# Demand: 13.44, Cash: 1396.79
# Action chosen: 1, Reward: -67.41
#
#  Test Episode 1 | Step 129
# Step: 129
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.36, Product Price: 20.84
# Demand: 18.66, Cash: 1392.23
# Action chosen: 1, Reward: -93.59
#
#  Test Episode 1 | Step 130
# Step: 130
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.71, Product Price: 20.62
# Demand: 8.67, Cash: 1413.07
# Action chosen: 2, Reward: -7.62
#
#  Test Episode 1 | Step 131
# Step: 131
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.96, Product Price: 20.58
# Demand: 10.12, Cash: 1408.36
# Action chosen: 1, Reward: -50.82
#
#  Test Episode 1 | Step 132
# Step: 132
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.04, Product Price: 20.60
# Demand: 11.06, Cash: 1403.40
# Action chosen: 1, Reward: -55.60
#
#  Test Episode 1 | Step 133
# Step: 133
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.96, Product Price: 20.70
# Demand: 12.02, Cash: 1423.99
# Action chosen: 2, Reward: -24.62
#
#  Test Episode 1 | Step 134
# Step: 134
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.02, Product Price: 20.60
# Demand: 8.31, Cash: 1419.04
# Action chosen: 1, Reward: -41.74
#
#  Test Episode 1 | Step 135
# Step: 135
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.32, Product Price: 20.50
# Demand: 6.32, Cash: 1414.01
# Action chosen: 1, Reward: -31.89
#
#  Test Episode 1 | Step 136
# Step: 136
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.40, Product Price: 20.80
# Demand: 9.32, Cash: 1434.51
# Action chosen: 2, Reward: -11.21
#
#  Test Episode 1 | Step 137
# Step: 137
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.46, Product Price: 20.60
# Demand: 2.66, Cash: 1429.11
# Action chosen: 1, Reward: -13.49
#
#  Test Episode 1 | Step 138
# Step: 138
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.19, Product Price: 20.35
# Demand: 8.29, Cash: 1423.65
# Action chosen: 1, Reward: -41.74
#
#  Test Episode 1 | Step 139
# Step: 139
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.07, Product Price: 20.37
# Demand: 9.13, Cash: 1444.00
# Action chosen: 2, Reward: -10.37
#
#  Test Episode 1 | Step 140
# Step: 140
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.18, Product Price: 20.42
# Demand: 12.17, Cash: 1438.93
# Action chosen: 1, Reward: -61.04
#
#  Test Episode 1 | Step 141
# Step: 141
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.24, Product Price: 20.57
# Demand: 11.24, Cash: 1433.75
# Action chosen: 1, Reward: -56.52
#
#  Test Episode 1 | Step 142
# Step: 142
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.04, Product Price: 20.53
# Demand: 13.95, Cash: 1454.32
# Action chosen: 2, Reward: -34.26
#
#  Test Episode 1 | Step 143
# Step: 143
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.11, Product Price: 20.74
# Demand: 10.86, Cash: 1449.28
# Action chosen: 1, Reward: -54.52
#
#  Test Episode 1 | Step 144
# Step: 144
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.86, Product Price: 20.52
# Demand: 4.34, Cash: 1444.17
# Action chosen: 1, Reward: -22.01
#
#  Test Episode 1 | Step 145
# Step: 145
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.77, Product Price: 20.29
# Demand: 4.36, Cash: 1464.68
# Action chosen: 2, Reward: 13.63
#
#  Test Episode 1 | Step 146
# Step: 146
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.92, Product Price: 20.18
# Demand: 10.68, Cash: 1459.92
# Action chosen: 1, Reward: -53.59
#
#  Test Episode 1 | Step 147
# Step: 147
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.98, Product Price: 20.09
# Demand: 12.54, Cash: 1455.00
# Action chosen: 1, Reward: -63.00
#
#  Test Episode 1 | Step 148
# Step: 148
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.85, Product Price: 20.07
# Demand: 11.06, Cash: 1475.09
# Action chosen: 2, Reward: -20.33
#
#  Test Episode 1 | Step 149
# Step: 149
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.37, Product Price: 20.06
# Demand: 11.89, Cash: 1470.23
# Action chosen: 1, Reward: -59.64
#
#  Test Episode 1 | Step 150
# Step: 150
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.43, Product Price: 19.96
# Demand: 8.90, Cash: 1464.86
# Action chosen: 1, Reward: -44.79
#
#  Test Episode 1 | Step 151
# Step: 151
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.22, Product Price: 20.03
# Demand: 14.78, Cash: 1484.82
# Action chosen: 2, Reward: -39.03
#
#  Test Episode 1 | Step 152
# Step: 152
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.59, Product Price: 20.05
# Demand: 16.51, Cash: 1479.60
# Action chosen: 1, Reward: -82.76
#
#  Test Episode 1 | Step 153
# Step: 153
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.64, Product Price: 20.25
# Demand: 7.50, Cash: 1474.01
# Action chosen: 1, Reward: -37.80
#
#  Test Episode 1 | Step 154
# Step: 154
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.64, Product Price: 19.97
# Demand: 5.17, Cash: 1494.26
# Action chosen: 2, Reward: 9.29
#
#  Test Episode 1 | Step 155
# Step: 155
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.59, Product Price: 19.89
# Demand: 9.31, Cash: 1488.63
# Action chosen: 1, Reward: -46.73
#
#  Test Episode 1 | Step 156
# Step: 156
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.92, Product Price: 19.84
# Demand: 13.05, Cash: 1483.03
# Action chosen: 1, Reward: -65.57
#
#  Test Episode 1 | Step 157
# Step: 157
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.86, Product Price: 19.66
# Demand: 13.40, Cash: 1502.87
# Action chosen: 2, Reward: -32.26
#
#  Test Episode 1 | Step 158
# Step: 158
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.77, Product Price: 19.47
# Demand: 9.76, Cash: 1497.00
# Action chosen: 1, Reward: -48.98
#
#  Test Episode 1 | Step 159
# Step: 159
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.53, Product Price: 19.83
# Demand: 8.76, Cash: 1491.23
# Action chosen: 1, Reward: -44.12
#
#  Test Episode 1 | Step 160
# Step: 160
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.42, Product Price: 19.73
# Demand: 12.22, Cash: 1511.06
# Action chosen: 2, Reward: -26.37
#
#  Test Episode 1 | Step 161
# Step: 161
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.32, Product Price: 19.96
# Demand: 4.54, Cash: 1505.64
# Action chosen: 1, Reward: -22.92
#
#  Test Episode 1 | Step 162
# Step: 162
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.39, Product Price: 19.94
# Demand: 6.04, Cash: 1500.32
# Action chosen: 1, Reward: -30.52
#
#  Test Episode 1 | Step 163
# Step: 163
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.28, Product Price: 20.30
# Demand: 8.64, Cash: 1520.26
# Action chosen: 2, Reward: -8.38
#
#  Test Episode 1 | Step 164
# Step: 164
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.69, Product Price: 20.72
# Demand: 5.80, Cash: 1514.98
# Action chosen: 1, Reward: -29.22
#
#  Test Episode 1 | Step 165
# Step: 165
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.43, Product Price: 20.73
# Demand: 9.27, Cash: 1509.29
# Action chosen: 1, Reward: -46.64
#
#  Test Episode 1 | Step 166
# Step: 166
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.22, Product Price: 20.95
# Demand: 10.62, Cash: 1530.02
# Action chosen: 2, Reward: -17.44
#
#  Test Episode 1 | Step 167
# Step: 167
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.82, Product Price: 20.77
# Demand: 9.49, Cash: 1524.81
# Action chosen: 1, Reward: -47.63
#
#  Test Episode 1 | Step 168
# Step: 168
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.77, Product Price: 20.79
# Demand: 7.65, Cash: 1519.99
# Action chosen: 1, Reward: -38.57
#
#  Test Episode 1 | Step 169
# Step: 169
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.80, Product Price: 21.00
# Demand: 9.37, Cash: 1540.77
# Action chosen: 2, Reward: -11.18
#
#  Test Episode 1 | Step 170
# Step: 170
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.85, Product Price: 21.09
# Demand: 4.35, Cash: 1535.97
# Action chosen: 1, Reward: -21.97
#
#  Test Episode 1 | Step 171
# Step: 171
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.99, Product Price: 21.06
# Demand: 11.57, Cash: 1557.06
# Action chosen: 2, Reward: -21.75
#
#  Test Episode 1 | Step 172
# Step: 172
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.92, Product Price: 21.27
# Demand: 10.07, Cash: 1552.07
# Action chosen: 1, Reward: -50.43
#
#  Test Episode 1 | Step 173
# Step: 173
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.02, Product Price: 21.47
# Demand: 10.70, Cash: 1547.14
# Action chosen: 1, Reward: -53.69
#
#  Test Episode 1 | Step 174
# Step: 174
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.96, Product Price: 21.22
# Demand: 10.01, Cash: 1568.61
# Action chosen: 2, Reward: -13.57
#
#  Test Episode 1 | Step 175
# Step: 175
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.06, Product Price: 21.12
# Demand: 11.26, Cash: 1563.65
# Action chosen: 1, Reward: -56.40
#
#  Test Episode 1 | Step 176
# Step: 176
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.91, Product Price: 20.96
# Demand: 9.67, Cash: 1558.59
# Action chosen: 1, Reward: -48.55
#
#  Test Episode 1 | Step 177
# Step: 177
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.07, Product Price: 21.09
# Demand: 13.32, Cash: 1579.55
# Action chosen: 2, Reward: -30.64
#
#  Test Episode 1 | Step 178
# Step: 178
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.30, Product Price: 20.88
# Demand: 9.52, Cash: 1574.48
# Action chosen: 1, Reward: -47.71
#
#  Test Episode 1 | Step 179
# Step: 179
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.43, Product Price: 20.91
# Demand: 13.55, Cash: 1569.19
# Action chosen: 1, Reward: -67.97
#
#  Test Episode 1 | Step 180
# Step: 180
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.54, Product Price: 20.97
# Demand: 8.20, Cash: 1590.09
# Action chosen: 2, Reward: -5.10
#
#  Test Episode 1 | Step 181
# Step: 181
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.37, Product Price: 21.12
# Demand: 15.34, Cash: 1584.55
# Action chosen: 1, Reward: -76.79
#
#  Test Episode 1 | Step 182
# Step: 182
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.35, Product Price: 20.94
# Demand: 9.79, Cash: 1579.18
# Action chosen: 1, Reward: -49.15
#
#  Test Episode 1 | Step 183
# Step: 183
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.39, Product Price: 21.07
# Demand: 7.09, Cash: 1600.12
# Action chosen: 2, Reward: 0.48
#
#  Test Episode 1 | Step 184
# Step: 184
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.64, Product Price: 20.45
# Demand: 10.00, Cash: 1594.73
# Action chosen: 1, Reward: -50.11
#
#  Test Episode 1 | Step 185
# Step: 185
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.77, Product Price: 20.16
# Demand: 4.30, Cash: 1589.09
# Action chosen: 1, Reward: -21.70
#
#  Test Episode 1 | Step 186
# Step: 186
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.76, Product Price: 20.28
# Demand: 8.78, Cash: 1583.32
# Action chosen: 1, Reward: -44.22
#
#  Test Episode 1 | Step 187
# Step: 187
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.68, Product Price: 19.86
# Demand: 12.08, Cash: 1603.60
# Action chosen: 2, Reward: -25.22
#
#  Test Episode 1 | Step 188
# Step: 188
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.84, Product Price: 19.89
# Demand: 11.38, Cash: 1597.92
# Action chosen: 1, Reward: -57.11
#
#  Test Episode 1 | Step 189
# Step: 189
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 5.96, Product Price: 19.88
# Demand: 7.22, Cash: 1592.08
# Action chosen: 1, Reward: -36.38
#
#  Test Episode 1 | Step 190
# Step: 190
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 6.13, Product Price: 20.13
# Demand: 9.14, Cash: 1611.96
# Action chosen: 2, Reward: -10.91
#
#  Test Episode 1 | Step 191
# Step: 191
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.63, Product Price: 20.15
# Demand: 3.78, Cash: 1605.83
# Action chosen: 1, Reward: -19.10
#
#  Test Episode 1 | Step 192
# Step: 192
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.97, Product Price: 20.15
# Demand: 10.73, Cash: 1599.20
# Action chosen: 1, Reward: -53.95
#
#  Test Episode 1 | Step 193
# Step: 193
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.07, Product Price: 20.07
# Demand: 12.47, Cash: 1619.34
# Action chosen: 2, Reward: -27.30
#
#  Test Episode 1 | Step 194
# Step: 194
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.24, Product Price: 19.59
# Demand: 13.82, Cash: 1612.27
# Action chosen: 1, Reward: -69.32
#
#  Test Episode 1 | Step 195
# Step: 195
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.27, Product Price: 19.12
# Demand: 9.61, Cash: 1605.03
# Action chosen: 1, Reward: -48.35
#
#  Test Episode 1 | Step 196
# Step: 196
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 6.76, Product Price: 18.97
# Demand: 10.05, Cash: 1624.14
# Action chosen: 2, Reward: -16.25
#
#  Test Episode 1 | Step 197
# Step: 197
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.71, Product Price: 18.82
# Demand: 11.03, Cash: 1617.38
# Action chosen: 1, Reward: -55.34
#
#  Test Episode 1 | Step 198
# Step: 198
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.70, Product Price: 18.85
# Demand: 10.73, Cash: 1610.67
# Action chosen: 1, Reward: -53.97
#
#  Test Episode 1 | Step 199
# Step: 199
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 6.44, Product Price: 18.78
# Demand: 10.52, Cash: 1629.52
# Action chosen: 2, Reward: -18.87
#
#  Test Episode 1 | Step 200
# Step: 200
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.25, Product Price: 19.07
# Demand: 11.04, Cash: 1623.09
# Action chosen: 1, Reward: -55.39
#
#  Test Episode 1 | Step 201
# Step: 201
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.26, Product Price: 19.17
# Demand: 7.26, Cash: 1616.84
# Action chosen: 1, Reward: -36.60
#
#  Test Episode 1 | Step 202
# Step: 202
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 6.47, Product Price: 19.25
# Demand: 17.46, Cash: 1636.01
# Action chosen: 2, Reward: -53.25
#
#  Test Episode 1 | Step 203
# Step: 203
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 6.61, Product Price: 19.37
# Demand: 8.77, Cash: 1629.54
# Action chosen: 1, Reward: -44.04
#
#  Test Episode 1 | Step 204
# Step: 204
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.01, Product Price: 19.75
# Demand: 7.39, Cash: 1622.93
# Action chosen: 1, Reward: -37.26
#
#  Test Episode 1 | Step 205
# Step: 205
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.29, Product Price: 20.46
# Demand: 4.50, Cash: 1642.68
# Action chosen: 2, Reward: 12.14
#
#  Test Episode 1 | Step 206
# Step: 206
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.34, Product Price: 20.55
# Demand: 8.55, Cash: 1635.39
# Action chosen: 1, Reward: -42.94
#
#  Test Episode 1 | Step 207
# Step: 207
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.50, Product Price: 20.10
# Demand: 4.38, Cash: 1655.94
# Action chosen: 2, Reward: 13.63
#
#  Test Episode 1 | Step 208
# Step: 208
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.49, Product Price: 20.69
# Demand: 8.45, Cash: 1648.44
# Action chosen: 1, Reward: -42.34
#
#  Test Episode 1 | Step 209
# Step: 209
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.46, Product Price: 20.99
# Demand: 8.08, Cash: 1640.95
# Action chosen: 1, Reward: -40.58
#
#  Test Episode 1 | Step 210
# Step: 210
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.98, Product Price: 20.93
# Demand: 6.40, Cash: 1661.94
# Action chosen: 2, Reward: 3.97
#
#  Test Episode 1 | Step 211
# Step: 211
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.93, Product Price: 21.03
# Demand: 12.11, Cash: 1653.96
# Action chosen: 1, Reward: -60.67
#
#  Test Episode 1 | Step 212
# Step: 212
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.93, Product Price: 20.95
# Demand: 7.31, Cash: 1646.03
# Action chosen: 1, Reward: -36.73
#
#  Test Episode 1 | Step 213
# Step: 213
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.99, Product Price: 20.80
# Demand: 10.60, Cash: 1666.98
# Action chosen: 2, Reward: -17.03
#
#  Test Episode 1 | Step 214
# Step: 214
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.79, Product Price: 21.23
# Demand: 1.96, Cash: 1658.99
# Action chosen: 1, Reward: -9.91
#
#  Test Episode 1 | Step 215
# Step: 215
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.48, Product Price: 21.13
# Demand: 6.74, Cash: 1651.20
# Action chosen: 1, Reward: -33.92
#
#  Test Episode 1 | Step 216
# Step: 216
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.45, Product Price: 21.38
# Demand: 11.99, Cash: 1672.33
# Action chosen: 2, Reward: -23.82
#
#  Test Episode 1 | Step 217
# Step: 217
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.69, Product Price: 21.24
# Demand: 6.97, Cash: 1664.88
# Action chosen: 1, Reward: -34.96
#
#  Test Episode 1 | Step 218
# Step: 218
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.63, Product Price: 21.41
# Demand: 9.64, Cash: 1657.19
# Action chosen: 1, Reward: -48.39
#
#  Test Episode 1 | Step 219
# Step: 219
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.77, Product Price: 21.61
# Demand: 10.49, Cash: 1678.60
# Action chosen: 2, Reward: -16.05
#
#  Test Episode 1 | Step 220
# Step: 220
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.77, Product Price: 21.34
# Demand: 9.33, Cash: 1670.83
# Action chosen: 1, Reward: -46.73
#
#  Test Episode 1 | Step 221
# Step: 221
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.97, Product Price: 21.51
# Demand: 7.98, Cash: 1663.06
# Action chosen: 1, Reward: -40.09
#
#  Test Episode 1 | Step 222
# Step: 222
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.84, Product Price: 21.89
# Demand: 9.02, Cash: 1684.57
# Action chosen: 2, Reward: -8.56
#
#  Test Episode 1 | Step 223
# Step: 223
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.93, Product Price: 21.99
# Demand: 7.93, Cash: 1676.73
# Action chosen: 1, Reward: -39.75
#
#  Test Episode 1 | Step 224
# Step: 224
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 8.21, Product Price: 22.07
# Demand: 7.54, Cash: 1668.80
# Action chosen: 1, Reward: -37.90
#
#  Test Episode 1 | Step 225
# Step: 225
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 8.00, Product Price: 22.44
# Demand: 9.11, Cash: 1690.86
# Action chosen: 2, Reward: -8.48
#
#  Test Episode 1 | Step 226
# Step: 226
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.64, Product Price: 22.41
# Demand: 11.32, Cash: 1682.87
# Action chosen: 1, Reward: -56.72
#
#  Test Episode 1 | Step 227
# Step: 227
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.58, Product Price: 22.03
# Demand: 9.84, Cash: 1675.23
# Action chosen: 1, Reward: -49.38
#
#  Test Episode 1 | Step 228
# Step: 228
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 7.71, Product Price: 21.80
# Demand: 6.67, Cash: 1697.26
# Action chosen: 2, Reward: 3.66
#
#  Test Episode 1 | Step 229
# Step: 229
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 7.79, Product Price: 21.66
# Demand: 9.64, Cash: 1689.54
# Action chosen: 1, Reward: -48.30
#
#  Test Episode 1 | Step 230
# Step: 230
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 8.03, Product Price: 21.63
# ...
#
#  Test Episode 10 | Step 426
# Step: 426
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.03, Product Price: 19.10
# Demand: 10.15, Cash: 2346.91
# Action chosen: 2, Reward: -16.73
#
#  Test Episode 10 | Step 427
# Step: 427
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.14, Product Price: 18.64
# Demand: 17.05, Cash: 2343.89
# Action chosen: 1, Reward: -85.37
#
#  Test Episode 10 | Step 428
# Step: 428
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.35, Product Price: 18.89
# Demand: 7.44, Cash: 2340.75
# Action chosen: 1, Reward: -37.39
#
#  Test Episode 10 | Step 429
# Step: 429
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.14, Product Price: 18.74
# Demand: 8.90, Cash: 2359.64
# Action chosen: 2, Reward: -10.59
#
#  Test Episode 10 | Step 430
# Step: 430
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.14, Product Price: 19.10
# Demand: 14.19, Cash: 2356.50
# Action chosen: 1, Reward: -71.06
#
#  Test Episode 10 | Step 431
# Step: 431
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.00, Product Price: 19.44
# Demand: 6.44, Cash: 2353.36
# Action chosen: 1, Reward: -32.40
#
#  Test Episode 10 | Step 432
# Step: 432
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.97, Product Price: 19.50
# Demand: 7.03, Cash: 2372.80
# Action chosen: 2, Reward: -0.70
#
#  Test Episode 10 | Step 433
# Step: 433
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.02, Product Price: 19.13
# Demand: 14.56, Cash: 2369.83
# Action chosen: 1, Reward: -72.92
#
#  Test Episode 10 | Step 434
# Step: 434
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.81, Product Price: 19.19
# Demand: 9.14, Cash: 2366.81
# Action chosen: 1, Reward: -45.89
#
#  Test Episode 10 | Step 435
# Step: 435
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.45, Product Price: 19.35
# Demand: 7.02, Cash: 2386.01
# Action chosen: 2, Reward: -0.90
#
#  Test Episode 10 | Step 436
# Step: 436
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.20, Product Price: 19.43
# Demand: 11.39, Cash: 2383.56
# Action chosen: 1, Reward: -57.03
#
#  Test Episode 10 | Step 437
# Step: 437
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.53, Product Price: 19.29
# Demand: 4.53, Cash: 2381.36
# Action chosen: 1, Reward: -22.83
#
#  Test Episode 10 | Step 438
# Step: 438
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.66, Product Price: 19.12
# Demand: 8.02, Cash: 2400.65
# Action chosen: 2, Reward: -5.82
#
#  Test Episode 10 | Step 439
# Step: 439
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.61, Product Price: 19.38
# Demand: 10.64, Cash: 2398.00
# Action chosen: 1, Reward: -53.29
#
#  Test Episode 10 | Step 440
# Step: 440
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.91, Product Price: 19.51
# Demand: 10.53, Cash: 2395.39
# Action chosen: 1, Reward: -52.84
#
#  Test Episode 10 | Step 441
# Step: 441
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.13, Product Price: 19.20
# Demand: 11.36, Cash: 2414.89
# Action chosen: 2, Reward: -22.29
#
#  Test Episode 10 | Step 442
# Step: 442
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.15, Product Price: 19.00
# Demand: 10.97, Cash: 2411.76
# Action chosen: 1, Reward: -54.95
#
#  Test Episode 10 | Step 443
# Step: 443
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.19, Product Price: 18.90
# Demand: 8.76, Cash: 2408.61
# Action chosen: 1, Reward: -44.00
#
#  Test Episode 10 | Step 444
# Step: 444
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.14, Product Price: 18.80
# Demand: 10.58, Cash: 2427.51
# Action chosen: 2, Reward: -18.99
#
#  Test Episode 10 | Step 445
# Step: 445
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.88, Product Price: 19.11
# Demand: 8.21, Cash: 2424.38
# Action chosen: 1, Reward: -41.17
#
#  Test Episode 10 | Step 446
# Step: 446
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.79, Product Price: 18.95
# Demand: 6.60, Cash: 2421.50
# Action chosen: 1, Reward: -33.21
#
#  Test Episode 10 | Step 447
# Step: 447
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.75, Product Price: 18.85
# Demand: 7.89, Cash: 2440.45
# Action chosen: 2, Reward: -5.50
#
#  Test Episode 10 | Step 448
# Step: 448
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.98, Product Price: 18.43
# Demand: 14.92, Cash: 2437.70
# Action chosen: 1, Reward: -74.69
#
#  Test Episode 10 | Step 449
# Step: 449
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.00, Product Price: 18.27
# Demand: 10.74, Cash: 2434.72
# Action chosen: 1, Reward: -53.89
#
#  Test Episode 10 | Step 450
# Step: 450
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.79, Product Price: 18.10
# Demand: 10.56, Cash: 2452.99
# Action chosen: 2, Reward: -19.54
#
#  Test Episode 10 | Step 451
# Step: 451
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.59, Product Price: 18.26
# Demand: 9.88, Cash: 2450.21
# Action chosen: 1, Reward: -49.49
#
#  Test Episode 10 | Step 452
# Step: 452
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.66, Product Price: 18.18
# Demand: 11.10, Cash: 2447.61
# Action chosen: 1, Reward: -55.68
#
#  Test Episode 10 | Step 453
# Step: 453
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.78, Product Price: 18.41
# Demand: 8.68, Cash: 2465.79
# Action chosen: 2, Reward: -10.23
#
#  Test Episode 10 | Step 454
# Step: 454
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.56, Product Price: 18.64
# Demand: 8.46, Cash: 2463.01
# Action chosen: 1, Reward: -42.39
#
#  Test Episode 10 | Step 455
# Step: 455
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.49, Product Price: 18.97
# Demand: 3.69, Cash: 2460.45
# Action chosen: 1, Reward: -18.64
#
#  Test Episode 10 | Step 456
# Step: 456
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.32, Product Price: 19.03
# Demand: 9.11, Cash: 2479.41
# Action chosen: 2, Reward: -11.59
#
#  Test Episode 10 | Step 457
# Step: 457
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.25, Product Price: 18.93
# Demand: 15.32, Cash: 2477.10
# Action chosen: 1, Reward: -76.69
#
#  Test Episode 10 | Step 458
# Step: 458
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.59, Product Price: 19.09
# Demand: 10.56, Cash: 2474.85
# Action chosen: 1, Reward: -53.02
#
#  Test Episode 10 | Step 459
# Step: 459
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.56, Product Price: 18.92
# Demand: 5.26, Cash: 2493.93
# Action chosen: 2, Reward: 7.77
#
#  Test Episode 10 | Step 460
# Step: 460
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.61, Product Price: 18.82
# Demand: 9.85, Cash: 2491.37
# Action chosen: 1, Reward: -49.36
#
#  Test Episode 10 | Step 461
# Step: 461
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.38, Product Price: 18.81
# Demand: 8.95, Cash: 2488.76
# Action chosen: 1, Reward: -44.95
#
#  Test Episode 10 | Step 462
# Step: 462
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.43, Product Price: 18.73
# Demand: 7.54, Cash: 2507.57
# Action chosen: 2, Reward: -3.90
#
#  Test Episode 10 | Step 463
# Step: 463
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.43, Product Price: 18.55
# Demand: 10.14, Cash: 2505.14
# Action chosen: 1, Reward: -50.81
#
#  Test Episode 10 | Step 464
# Step: 464
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.37, Product Price: 18.29
# Demand: 5.81, Cash: 2502.71
# Action chosen: 1, Reward: -29.27
#
#  Test Episode 10 | Step 465
# Step: 465
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.41, Product Price: 18.33
# Demand: 10.90, Cash: 2521.01
# Action chosen: 2, Reward: -21.22
#
#  Test Episode 10 | Step 466
# Step: 466
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.38, Product Price: 18.13
# Demand: 12.07, Cash: 2518.60
# Action chosen: 1, Reward: -60.44
#
#  Test Episode 10 | Step 467
# Step: 467
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.62, Product Price: 18.17
# Demand: 8.12, Cash: 2516.22
# Action chosen: 1, Reward: -40.82
#
#  Test Episode 10 | Step 468
# Step: 468
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.69, Product Price: 18.15
# Demand: 13.27, Cash: 2534.39
# Action chosen: 2, Reward: -33.17
#
#  Test Episode 10 | Step 469
# Step: 469
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.79, Product Price: 18.02
# Demand: 12.99, Cash: 2531.70
# Action chosen: 1, Reward: -65.07
#
#  Test Episode 10 | Step 470
# Step: 470
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.61, Product Price: 18.01
# Demand: 7.22, Cash: 2528.90
# Action chosen: 1, Reward: -36.30
#
#  Test Episode 10 | Step 471
# Step: 471
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.74, Product Price: 17.77
# Demand: 11.31, Cash: 2546.92
# Action chosen: 2, Reward: -23.51
#
#  Test Episode 10 | Step 472
# Step: 472
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.74, Product Price: 17.38
# Demand: 2.98, Cash: 2544.17
# Action chosen: 1, Reward: -14.99
#
#  Test Episode 10 | Step 473
# Step: 473
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.15, Product Price: 17.21
# Demand: 0.98, Cash: 2541.44
# Action chosen: 1, Reward: -5.12
#
#  Test Episode 10 | Step 474
# Step: 474
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 2.33, Product Price: 17.34
# Demand: 10.39, Cash: 2558.65
# Action chosen: 2, Reward: -19.73
#
#  Test Episode 10 | Step 475
# Step: 475
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.49, Product Price: 17.47
# Demand: 7.87, Cash: 2556.32
# Action chosen: 1, Reward: -39.44
#
#  Test Episode 10 | Step 476
# Step: 476
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.47, Product Price: 17.27
# Demand: 8.60, Cash: 2553.83
# Action chosen: 1, Reward: -43.18
#
#  Test Episode 10 | Step 477
# Step: 477
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.95, Product Price: 17.46
# Demand: 9.04, Cash: 2571.09
# Action chosen: 2, Reward: -12.93
#
#  Test Episode 10 | Step 478
# Step: 478
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.91, Product Price: 17.37
# Demand: 9.61, Cash: 2569.14
# Action chosen: 1, Reward: -48.16
#
#  Test Episode 10 | Step 479
# Step: 479
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.72, Product Price: 17.54
# Demand: 11.16, Cash: 2567.23
# Action chosen: 1, Reward: -56.02
#
#  Test Episode 10 | Step 480
# Step: 480
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.96, Product Price: 17.35
# Demand: 11.01, Cash: 2584.77
# Action chosen: 2, Reward: -22.53
#
#  Test Episode 10 | Step 481
# Step: 481
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.79, Product Price: 17.08
# Demand: 5.05, Cash: 2582.81
# Action chosen: 1, Reward: -25.37
#
#  Test Episode 10 | Step 482
# Step: 482
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.73, Product Price: 17.24
# Demand: 11.77, Cash: 2581.02
# Action chosen: 1, Reward: -59.07
#
#  Test Episode 10 | Step 483
# Step: 483
# Raw Inventory: 3.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.47, Product Price: 17.23
# Demand: 8.03, Cash: 2579.28
# Action chosen: 1, Reward: -40.47
#
#  Test Episode 10 | Step 484
# Step: 484
# Raw Inventory: 1.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.60, Product Price: 17.15
# Demand: 8.98, Cash: 2596.51
# Action chosen: 2, Reward: -12.79
#
#  Test Episode 10 | Step 485
# Step: 485
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.81, Product Price: 17.32
# Demand: 6.46, Cash: 2594.91
# Action chosen: 1, Reward: -32.48
#
#  Test Episode 10 | Step 486
# Step: 486
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.72, Product Price: 17.06
# Demand: 6.62, Cash: 2612.24
# Action chosen: 2, Reward: -0.78
#
#  Test Episode 10 | Step 487
# Step: 487
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.71, Product Price: 17.26
# Demand: 8.92, Cash: 2610.52
# Action chosen: 1, Reward: -44.70
#
#  Test Episode 10 | Step 488
# Step: 488
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.68, Product Price: 17.53
# Demand: 12.45, Cash: 2608.81
# Action chosen: 1, Reward: -62.43
#
#  Test Episode 10 | Step 489
# Step: 489
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.60, Product Price: 17.61
# Demand: 6.96, Cash: 2626.34
# Action chosen: 2, Reward: -2.26
#
#  Test Episode 10 | Step 490
# Step: 490
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.52, Product Price: 17.96
# Demand: 11.30, Cash: 2624.73
# Action chosen: 1, Reward: -56.61
#
#  Test Episode 10 | Step 491
# Step: 491
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.60, Product Price: 18.25
# Demand: 11.52, Cash: 2623.21
# Action chosen: 1, Reward: -57.82
#
#  Test Episode 10 | Step 492
# Step: 492
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.87, Product Price: 18.30
# Demand: 8.51, Cash: 2641.45
# Action chosen: 2, Reward: -9.30
#
#  Test Episode 10 | Step 493
# Step: 493
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.89, Product Price: 18.28
# Demand: 11.47, Cash: 2639.59
# Action chosen: 1, Reward: -57.44
#
#  Test Episode 10 | Step 494
# Step: 494
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 2.10, Product Price: 18.52
# Demand: 4.58, Cash: 2637.70
# Action chosen: 1, Reward: -23.10
#
#  Test Episode 10 | Step 495
# Step: 495
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.95, Product Price: 18.33
# Demand: 11.22, Cash: 2656.21
# Action chosen: 2, Reward: -22.57
#
#  Test Episode 10 | Step 496
# Step: 496
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.67, Product Price: 18.50
# Demand: 12.91, Cash: 2654.26
# Action chosen: 1, Reward: -64.66
#
#  Test Episode 10 | Step 497
# Step: 497
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.78, Product Price: 18.69
# Demand: 11.53, Cash: 2652.59
# Action chosen: 1, Reward: -57.86
#
#  Test Episode 10 | Step 498
# Step: 498
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 1.50, Product Price: 18.93
# Demand: 11.06, Cash: 2671.28
# Action chosen: 2, Reward: -21.62
#
#  Test Episode 10 | Step 499
# Step: 499
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.67, Product Price: 19.04
# Demand: 12.64, Cash: 2669.78
# Action chosen: 1, Reward: -63.31
#
#  Test Episode 10 | Step 500
# Step: 500
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 1.76, Product Price: 19.25
# Demand: 11.67, Cash: 2668.10
# Action chosen: 1, Reward: -58.57
# Test Episode 10 finished | Total reward: -18997.85
# Test episode rewards: [-19170.266300173225, -19233.410727232673, -19644.732391897807, -18759.322700504963, -19645.726727997888, -18228.70353537898, -20994.900863886534, -18807.14889567644, -19543.321920752976, -18997.846758776916]

# %% [markdown]
# Assignment asks for the questions to be put into a cell, does it mean code or markdown? I did markdown.
#
# 1. The biggest challenges I faced was unfortunately my laptop crashing every 45minutes(still troubleshooting it). But in regards to the assignment the challenges were balancing the exploration vs exploitation since the agnet needed enough exploration to find and discover new strategies, but not enough to hurt it later. Another issue which unfortunatley I couldn't solve we convergance time since the agent wouldve needed 5000+ episodes to converge and stabilize but the best option for me due to repeated crashing (BSOD) I had to settle with 2000 episodes. Some of the biggest takeaways were that the replay buffer is essential for stable learning in continuous state spaces. And also hyperparameter tuning (learning rate, epsilon decay, batch size) significantly impacts convergence speed and final performance.
#
# 2. Test episode rewards: [-19170.266300173225, -19233.410727232673, -19644.732391897807, -18759.322700504963, -19645.726727997888, -18228.70353537898, -20994.900863886534, -18807.14889567644, -19543.321920752976, -18997.846758776916]
# This shows that the training policy demonstrated learned behaviors in managing inventory under a changing market with prices and demand. Training showed convergence with the rewards improivng from -12,156 to -11,834 after 50 episodes and continued stabilizing. The mse loss decreased, and the rewards remained negative due to penaltiesbut the agent learned to minimize loess, while a training time to 5000 episodes would have likely improved preformace this was the best avaible solution for the time being.
#
# 3. Not in my feild (BSEE) but a cool application I see a lot of news on is that Proteins fold into 3D shapes that determine their function. And RL can try different folding patterns and reward closer matches to the real shape, helping predict structures fast. Knowing the shape helps scientists design drugs that fits which helps speed up the process. In my domain it could help find chemical compisitions to make and test for various types of battery electrodes, since there are so many different ratios of metals you can use with each varying and altering the output of what the battery could expereince in terms of mAH ,cycle life, and also charging rate. This would allow for more variety in batteries shortening the time to develop and test the most optimal ratios.
