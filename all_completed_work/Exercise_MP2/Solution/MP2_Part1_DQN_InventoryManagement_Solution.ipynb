# %% [markdown]
# #### MP2 Solution - Part 1 RL in Inventory Management

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import matplotlib.pyplot as plt
from Inventory_env_class import InventoryManagementEnv, NormalizeObservation, ReplayBuffer, DQN

# %%
# Hyperparameters 
num_episodes = 3000
batch_size = 64
gamma = 0.75
learning_rate = 1e-3
buffer_capacity = 100000
target_update_freq = 30  # update target network every 30 episodes
epsilon_start = 1.0
epsilon_final = 0.01
epsilon_decay = 100000  # slower decay to encourage exploration
frame_idx = 0

# %%
# epsilon decay function
# def get_epsilon(frame_idx):
#     return epsilon_final + (epsilon_start - epsilon_final) * np.exp(-1.0 * frame_idx / epsilon_decay)
def get_epsilon(frame_idx):
    epsilon_start = 1.0
    epsilon_end = 0.05
    epsilon_decay = 100_000  # much slower
    return epsilon_end + (epsilon_start - epsilon_end) * np.exp(-1. * frame_idx / epsilon_decay)

# %%
# Create environment and wrap with normalization.
env = InventoryManagementEnv()
env = NormalizeObservation(env)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_dim = env.observation_space.shape[0]  # should be 6
output_dim = env.action_space.n             # should be 3

policy_net = DQN(input_dim, output_dim).to(device)
target_net = DQN(input_dim, output_dim).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)
replay_buffer = ReplayBuffer(buffer_capacity)

all_rewards = []
losses = []       # to record loss per update
q_values_log = [] # record average Q-values per update - when Q-values from the model and avg. Q-net losses stabilize, hints at convergence

# %%
# Training Setup and Loop

for episode in range(num_episodes):
    obs, _ = env.reset()
    state = obs
    episode_reward = 0
    done = False
    truncated = False

    while not (done or truncated):
        frame_idx += 1
        epsilon = get_epsilon(frame_idx)
        # Epsilon-greedy action selection
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
            with torch.no_grad():
                q_vals = policy_net(state_tensor)
            action = q_vals.max(1)[1].item()
        
        next_obs, reward, done, truncated, _ = env.step(action)
        next_state = next_obs
        replay_buffer.push(state, action, reward, next_state, done or truncated)
        state = next_state
        episode_reward += reward

        # Update the network if enough samples are available
        if len(replay_buffer) > batch_size:
            states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
            states = torch.FloatTensor(states).to(device)
            actions = torch.LongTensor(actions).unsqueeze(1).to(device)
            rewards = torch.FloatTensor(rewards).unsqueeze(1).to(device)
            next_states = torch.FloatTensor(next_states).to(device)
            dones = torch.FloatTensor(dones).unsqueeze(1).to(device)

            # Current Q values from policy network
            q_values = policy_net(states).gather(1, actions)
            
            # Next state Q values from target network
            with torch.no_grad():
                next_q_values = target_net(next_states).max(1)[0].unsqueeze(1)
            expected_q_values = rewards + gamma * next_q_values * (1 - dones)

            loss = nn.MSELoss()(q_values, expected_q_values)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            losses.append(loss.item())
            q_values_log.append(q_values.mean().item())

    all_rewards.append(episode_reward)
    
    # Update target network weights 
    if episode % target_update_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())
        
    # Print progress every 50 episodes. 
    # What metrics you look at is up to you and I chose rewards, how the Q-net is training and if the Q-Values are stailizing around a value.
    # For convenience I am checking the average of last 50 values in the lists
    if episode % 50 == 0:
        avg_loss = np.mean(losses[-50:]) if losses else 0  
        avg_q = np.mean(q_values_log[-50:]) if q_values_log else 0
        print(f"Episode {episode}, Reward: {episode_reward:.2f}, Epsilon: {epsilon:.2f}, Avg Loss: {avg_loss:.4f}, Avg Q: {avg_q:.4f}")

# Episode 2650, Reward: -19702.88, Epsilon: 0.05, Avg Loss: 230.5775, Avg Q: -151.9343
# Episode 2700, Reward: -19251.11, Epsilon: 0.05, Avg Loss: 241.9804, Avg Q: -150.4076
# Episode 2750, Reward: -18708.71, Epsilon: 0.05, Avg Loss: 229.4785, Avg Q: -151.7950
# Episode 2800, Reward: -20437.55, Epsilon: 0.05, Avg Loss: 254.0179, Avg Q: -153.3316
# Episode 2850, Reward: -19852.13, Epsilon: 0.05, Avg Loss: 256.7089, Avg Q: -153.3757
# Episode 2900, Reward: -19234.88, Epsilon: 0.05, Avg Loss: 270.2817, Avg Q: -152.7851
# Episode 2950, Reward: -19964.33, Epsilon: 0.05, Avg Loss: 255.6693, Avg Q: -153.6231
# Training completed!

# %%
# Plotting Training Metrics

indices_rewards = range(0, len(all_rewards), 100)  # Get indices for every 100th element to make plot readable
values_to_plot_rewards = [all_rewards[i] for i in indices_rewards]  # Extract values at those indices

indices_losses = range(0, len(losses), 10000)  # Get indices for every 100th element
values_to_plot_losses = [losses[i] for i in indices_losses]  # Extract values at those indices

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
# plt.plot(all_rewards)
plt.plot(values_to_plot_rewards)
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("Learning Curve (Reward per Episode)")

plt.subplot(1,2,2)
# plt.plot(losses)
plt.plot(values_to_plot_losses)
plt.xlabel("Training Update")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.tight_layout()
plt.show()

# %%
# Policy Demonstration

obs, _ = env.reset()
state = obs
print("\nPolicy demonstration:")
for episode in range(30):
    state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
    with torch.no_grad():
        q_vals = policy_net(state_tensor)
    action = q_vals.max(1)[1].item()
    print(f"\nEpisode {episode+1} | Action taken: {action}")
    next_obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    if terminated or truncated:
        break
    state = next_obs
# Out:
# Policy demonstration:
#
# Episode 1 | Action taken: 1
# Step: 1
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.63, Product Price: 19.25
# Demand: 11.91, Cash: 995.15
#
# Episode 2 | Action taken: 1
# Step: 2
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.61, Product Price: 19.24
# Demand: 10.15, Cash: 990.52
#
# Episode 3 | Action taken: 2
# Step: 3
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.34, Product Price: 19.15
# Demand: 5.98, Cash: 1009.77
#
# Episode 4 | Action taken: 1
# Step: 4
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.45, Product Price: 18.75
# Demand: 9.58, Cash: 1005.43
#
# Episode 5 | Action taken: 1
# Step: 5
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.25, Product Price: 18.60
# Demand: 12.94, Cash: 1000.98
#
# Episode 6 | Action taken: 2
# Step: 6
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.64, Product Price: 18.35
# Demand: 15.16, Cash: 1019.58
#
# Episode 7 | Action taken: 1
# Step: 7
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.61, Product Price: 18.21
# Demand: 9.22, Cash: 1014.94
#
# Episode 8 | Action taken: 1
# Step: 8
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.88, Product Price: 18.29
# Demand: 11.36, Cash: 1010.33
#
# Episode 9 | Action taken: 2
# Step: 9
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 5.05, Product Price: 18.23
# Demand: 8.70, Cash: 1028.62
#
# Episode 10 | Action taken: 1
# Step: 10
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.53, Product Price: 18.39
# Demand: 13.48, Cash: 1023.57
#
# Episode 11 | Action taken: 1
# Step: 11
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.35, Product Price: 18.42
# Demand: 10.34, Cash: 1019.04
#
# Episode 12 | Action taken: 2
# Step: 12
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.12, Product Price: 18.38
# Demand: 10.37, Cash: 1037.45
#
# Episode 13 | Action taken: 1
# Step: 13
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.34, Product Price: 18.24
# Demand: 12.42, Cash: 1033.33
#
# Episode 14 | Action taken: 1
# Step: 14
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.25, Product Price: 17.66
# Demand: 11.54, Cash: 1028.99
#
# Episode 15 | Action taken: 2
# Step: 15
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.29, Product Price: 17.68
# Demand: 12.59, Cash: 1046.65
#
# Episode 16 | Action taken: 1
# Step: 16
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.08, Product Price: 17.91
# Demand: 7.65, Cash: 1042.36
#
# Episode 17 | Action taken: 1
# Step: 17
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.75, Product Price: 17.90
# Demand: 17.20, Cash: 1038.28
#
# Episode 18 | Action taken: 2
# Step: 18
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.94, Product Price: 17.79
# Demand: 12.27, Cash: 1056.18
#
# Episode 19 | Action taken: 1
# Step: 19
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.90, Product Price: 17.94
# Demand: 10.08, Cash: 1052.24
#
# Episode 20 | Action taken: 1
# Step: 20
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.26, Product Price: 18.11
# Demand: 9.80, Cash: 1048.35
#
# Episode 21 | Action taken: 2
# Step: 21
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.22, Product Price: 18.34
# Demand: 12.93, Cash: 1066.46
#
# Episode 22 | Action taken: 1
# Step: 22
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.27, Product Price: 18.37
# Demand: 8.67, Cash: 1062.24
#
# Episode 23 | Action taken: 1
# Step: 23
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.97, Product Price: 18.23
# Demand: 4.68, Cash: 1057.97
#
# Episode 24 | Action taken: 2
# Step: 24
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.01, Product Price: 18.04
# Demand: 13.38, Cash: 1076.19
#
# Episode 25 | Action taken: 1
# Step: 25
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.90, Product Price: 17.66
# Demand: 11.69, Cash: 1072.18
#
# Episode 26 | Action taken: 1
# Step: 26
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.58, Product Price: 17.76
# Demand: 14.80, Cash: 1068.28
#
# Episode 27 | Action taken: 2
# Step: 27
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 3.61, Product Price: 17.65
# Demand: 7.27, Cash: 1086.04
#
# Episode 28 | Action taken: 1
# Step: 28
# Raw Inventory: 1.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 3.81, Product Price: 17.52
# Demand: 13.45, Cash: 1082.43
#
# Episode 29 | Action taken: 1
# Step: 29
# Raw Inventory: 2.0
# Product Inventory Before Sale: 0.0, After Sale: 0.0
# Raw Price: 4.30, Product Price: 17.57
# Demand: 13.17, Cash: 1078.62
#
# Episode 30 | Action taken: 2
# Step: 30
# Raw Inventory: 0.0
# Product Inventory Before Sale: 1.0, After Sale: 0.0
# Raw Price: 4.08, Product Price: 17.70
# Demand: 15.98, Cash: 1096.19

# %%
# Save the model's state_dict
torch.save(policy_net.state_dict(), 'inv_model_state_dict.pth')

# To save the entire model
torch.save(policy_net, 'inv_entire_model.pth')
